# %%
import numpy as np
x = np.array(1)
x.ndim

# %%
import weakref
import numpy as np

a = np.array([1,2,3])
b = weakref.ref(a)

print(b)
print(b())

a = None
print(a)
print(b)
# Out:
# <weakref at 0x7c8208c5e660; to 'numpy.ndarray' at 0x7c82092df7b0>
# [1 2 3]
# None
# <weakref at 0x7c8208c5e660; dead>

# %%
import contextlib

@contextlib.contextmanager
def config_test():
    print('start')
    try:
        yield
    finally:
        print('done')

with config_test():
    print('process...')
# Out:
# start
# process...
# done

# %%
import numpy as np
from dezero.core_simple import Variable
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_5384/2638969470.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 from dezero.core_simple import Variable
#
# ImportError: cannot import name 'Variable' from 'dezero.core_simple' (/kaggle/working/deep_learning_from_scratch_3/dezero/core_simple.py)
