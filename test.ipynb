# %%
import numpy as np
x = np.array(1)
x.ndim

# %%
import weakref
import numpy as np

a = np.array([1,2,3])
b = weakref.ref(a)

print(b)
print(b())

a = None
print(a)
print(b)
# Out:
# <weakref at 0x7c8208c5e660; to 'numpy.ndarray' at 0x7c82092df7b0>
# [1 2 3]
# None
# <weakref at 0x7c8208c5e660; dead>
